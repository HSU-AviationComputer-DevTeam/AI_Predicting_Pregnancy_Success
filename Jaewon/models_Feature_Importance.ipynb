# %% [markdown]
# xgboost -- 가중치 컬럼 4개 ['이식된 배아 수', '배아 이식 경과일', '총 생성 배아 수', '혼합된 난자 수'] (log 2.5배)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. 이식된 배아수
# 2. 신선배아사용여부
# 3. 동결배아사용여부
# 4. 배아이식경과일
# 5. 저장된배아수
# 6. 난자출처
# 7. 시술당시나이
# 8. 시술유형
# 9. 총생성배아수
# 10. 배아생성주요이유
#
#
# 11. 이식배아경과일상호작용
# 12. 미세주입 배아 이식 수
# 13. 수집된신선난자수
# plt폰트깨짐

# %% [markdown]
# xgboost -- 가중치 컬럼 7개
#
# ['이식된 배아 수', '배아 이식 경과일',
#  '총 생성 배아 수', '혼합된 난자 수', '단일 배아 이식 여부', '파트너 정자와 혼합된 난자 수', '미세주입에서 생성된 배아 수']
#   (log 2.5배)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. 이식된배아수
# 2. 동결배아사용여부
# 3. 배아이식경과일
# 4. 신선배아사용여부
# 5. 난자출처
# 6. 저장된배아수
# 7. 배아생성주요이유
# 8. 시술당시나이
# 9. 총생성배아수
# 10. 미세주입배아이식수

# %% [markdown]
# xgboost -- 가중치 컬럼 7개  (수정)
#
# important_features = ['이식된 배아 수', '동결 배아 사용 여부', '배아 이식 경과일', '신선 배아 사용 여부', '난자 출처,' '저장된 배아 수', '시술 당시 나이']
#
#   (log 2.5배)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# test3_1 모델 컬럼 별 중요도

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# test3_1_lightgbm_1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
